# %% [markdown]
# # View WB, IMF and Covid data combined
#
# Data is previoiusly saved locally in CSV format, where columns are 'Country or Area', 'Item', 'Year', 'Value'.

# %%
import pandas as pd

df=pd.read_csv('IMF_statistics.csv')
df=df.append(pd.read_csv('WB_statistics.csv'))
df=df.append(pd.read_csv('Covid_statistics.csv'))
print('Number of datapoints:',df.shape[0])
# Out:
# Number of datapoints: 5425

# %%
print('Indicators in data')
indicators=df.Item.unique()
for x in indicators:
    print(' ',x)
    print('    years:',df[df.Item==x].Year.unique())
# Out:
# Indicators in data
#   Central Government Debt (Percent of GDP)
#     years: [2017 2018 2019]
#   Real GDP growth (Annual percent change)
#     years: [2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
#   International tourism, number of arrivals
#     years: [2018 2019 2020]
#   Unemployment, total (% of total labor force) (modeled ILO estimate)
#     years: [2018 2019 2020]
#   GDP per capita (current US$)
#     years: [2018 2019 2020]
#   people_vaccinated_per_hundred
#     years: [2021]

# %%
df.to_csv('Combined_statistics.csv', index=False)

countries=df['Country or Area'].unique()
print('Number of countries or areas in data:',len(countries))
df[df['Country or Area']=='Finland']
# Out:
# Number of countries or areas in data: 348
#      Country or Area         Value  Year  \
# 53           Finland     51.034599  2017
# 228          Finland     49.337077  2018
# 403          Finland     49.128897  2019
# 583          Finland           3.2  2017
# 811          Finland           1.3  2018
# 1039         Finland           1.3  2019
# 1267         Finland          -2.9  2020
# 1495         Finland           2.3  2021
# 1723         Finland           2.5  2022
# 1951         Finland           1.5  2023
# 2179         Finland           1.3  2024
# 2407         Finland           1.3  2025
# 2635         Finland           1.3  2026
# 225          Finland     3224000.0  2018
# 226          Finland     3290000.0  2019
# 227          Finland           NaN  2020
# 1023         Finland          7.36  2018
# 1024         Finland           6.7  2019
# 1025         Finland          7.83  2020
# 1821         Finland  50013.294203  2018
# 1822         Finland  48711.564208  2019
# 1823         Finland  49041.342257  2020
# 71           Finland         73.98  2021
#
#                                                    Item
# 53             Central Government Debt (Percent of GDP)
# 228            Central Government Debt (Percent of GDP)
# 403            Central Government Debt (Percent of GDP)
# 583             Real GDP growth (Annual percent change)
# 811             Real GDP growth (Annual percent change)
# 1039            Real GDP growth (Annual percent change)
# 1267            Real GDP growth (Annual percent change)
# 1495            Real GDP growth (Annual percent change)
# 1723            Real GDP growth (Annual percent change)
# 1951            Real GDP growth (Annual percent change)
# 2179            Real GDP growth (Annual percent change)
# 2407            Real GDP growth (Annual percent change)
# 2635            Real GDP growth (Annual percent change)
# 225           International tourism, number of arrivals
# 226           International tourism, number of arrivals
# 227           International tourism, number of arrivals
# 1023  Unemployment, total (% of total labor force) (...
# 1024  Unemployment, total (% of total labor force) (...
# 1025  Unemployment, total (% of total labor force) (...
# 1821                       GDP per capita (current US$)
# 1822                       GDP per capita (current US$)
# 1823                       GDP per capita (current US$)
# 71                        people_vaccinated_per_hundred
